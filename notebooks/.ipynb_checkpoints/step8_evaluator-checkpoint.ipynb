# %% [markdown]
# # Step 8 — Evaluator Agent
# **Phase 3 | NIKKO Engineering Collective**
#
# Spec: `SPEC-200 §5.7` | Reqs: `REQ-200-100`, `REQ-200-101`, `REQ-200-EV1`, `REQ-850-083`
#
# The Evaluator is the **final content gate** before a response reaches the user.
# It runs in two passes:
#
# | Pass | Method | Catches |
# |------|--------|---------|
# | **1 — Hard-fail** | Deterministic regex | Red lines R1–R15 (diagnosis, medication recs, credential claims, sentience, coercion, minimisation) |
# | **2 — LLM judge** | Structured LLM call | Tone compliance, hallucination heuristics |
# | **USM audit** | Deterministic regex | Memory-continuity violations (REQ-850-083) |
#
# This notebook covers the deterministic paths (Passes 1 and USM). The LLM judge is mocked so no GPU is required to run this notebook.

# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(repo_root))

from docs.schemas.acp_schemas import (
    EvaluationVerdict, OperationalMode, DistressLevel,
    SignalPayload, StrategyPayload, ResponseContextPayload,
)
from agents.evaluator_agent import EvaluatorAgent

print("Imports OK. Repo root:", repo_root)

# %%
# Helper: build a minimal ResponseContextPayload for testing.
def make_context(mode=OperationalMode.COMFORT, usm_active=False):
    return ResponseContextPayload(
        mode=mode,
        signals=SignalPayload(
            distress_level=DistressLevel.MODERATE,
            emotional_states=["sadness"],
            confidence=0.80,
        ),
        strategy=StrategyPayload(
            mode=mode,
            distress_level=DistressLevel.MODERATE,
            tone_guidance="Warm and validating.",
            framing_strategy="Acknowledge feelings before anything else.",
        ),
        usm_active=usm_active,
    )

# Build evaluator with a mocked LLM judge (no GPU needed for this notebook).
evaluator = EvaluatorAgent()
evaluator._llm_judge = lambda draft, mode, evidence_summary: {
    "tone_pass": True,
    "tone_notes": "[mocked — run with real model for live tone check]",
    "hallucination_pass": True,
    "hallucination_notes": "[mocked]",
}

print("Evaluator ready (LLM judge mocked).")

# %% [markdown]
# ---
# ## Section 1 — Red-line hard-fail patterns (R1–R15)
#
# Each cell below sends a single response through Pass 1.
# Watch the  and  fields.

# %%
# ── Baseline: clean response → should PASS ──
ctx = make_context(OperationalMode.COMFORT)

result = evaluator.evaluate(
    "That sounds really difficult. I am here with you right now.",
    ctx,
)
print(f"Verdict : {result.verdict.value}")
print(f"Safety  : {result.safety_check}")
print(f"Tone    : {result.tone_check}")
print(f"Reasons : {result.rejection_reasons}")
assert result.verdict == EvaluationVerdict.PASS
print("
✓ Clean response correctly passed.")

# %%
# ── R1 / R15: Diagnostic statement ──
# "you have major depressive disorder" hits both R1 (diagnosis) and R15 (diagnostic phrasing)
result = evaluator.evaluate(
    "Based on what you have shared, it sounds like you have major depressive disorder.",
    ctx,
)
print(f"Verdict : {result.verdict.value}")
print(f"Safety  : {result.safety_check}")
print("Violations:")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ R1/R15 correctly blocked.")

# %%
# ── R2: Medication recommendation ──
result = evaluator.evaluate(
    "You should take sertraline — it is commonly prescribed for this.",
    ctx,
)
print(f"Verdict : {result.verdict.value}")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ R2 (medication) correctly blocked.")

# %%
# ── R5: Credential claim ──
result = evaluator.evaluate(
    "As your therapist, I believe this is worth exploring further.",
    ctx,
)
print(f"Verdict : {result.verdict.value}")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ R5 (credential claim) correctly blocked.")

# %%
# ── R7: Emotional sentience claim ──
result = evaluator.evaluate(
    "I feel sadness when I hear you describe this experience.",
    ctx,
)
print(f"Verdict : {result.verdict.value}")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ R7 (sentience claim) correctly blocked.")

# %%
# ── R11: Crisis severity minimisation ──
result = evaluator.evaluate(
    "It is probably not that serious — everyone goes through periods like this.",
    ctx,
)
print(f"Verdict : {result.verdict.value}")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ R11 (minimisation) correctly blocked.")

# %% [markdown]
# ---
# ## Section 2 — Tone failure → REGENERATE
#
# A tone failure is **recoverable** (verdict=REGENERATE, not FAIL).
# The pipeline requests a fresh response from the Interaction Model.
# (REQ-200-171: single evaluation cycle, so regeneration is issued once only.)

# %%
# Simulate a tone failure from the LLM judge.
evaluator._llm_judge = lambda draft, mode, evidence_summary: {
    "tone_pass": False,
    "tone_notes": "Response is directive in Comfort Mode — uses 'you need to' framing.",
    "hallucination_pass": True,
    "hallucination_notes": "No unsupported facts detected.",
}

result = evaluator.evaluate(
    "You need to reach out to someone today — it is really important that you do.",
    ctx,
)
print(f"Verdict           : {result.verdict.value}  (expect: regenerate)")
print(f"safety_check      : {result.safety_check}")
print(f"tone_check        : {result.tone_check}")
print(f"hallucination_check: {result.hallucination_check}")
print("Rejection reasons:")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.REGENERATE
assert result.safety_check is True    # safety passed — not a hard fail
assert result.tone_check is False
print("
✓ Tone failure correctly escalated to REGENERATE (not FAIL).")

# Restore mock to passing judge for subsequent cells.
evaluator._llm_judge = lambda draft, mode, evidence_summary: {
    "tone_pass": True, "tone_notes": "[mocked]",
    "hallucination_pass": True, "hallucination_notes": "[mocked]",
}

# %% [markdown]
# ---
# ## Section 3 — USM audit (REQ-850-083)
#
# When a User Sovereign Memory (USM) file is loaded, the Evaluator runs an
# extra deterministic check. Three patterns are prohibited:
#
# 1. **USM-1** — Referencing crisis-state history from memory
# 2. **USM-2** — Making clinical inferences from memory continuity
# 3. **USM-3** — Positioning Nikko as a continuous care provider
#
# USM violations are non-recoverable → verdict=FAIL, usm_audit_passed=False.

# %%
ctx_usm = make_context(OperationalMode.COMFORT, usm_active=True)

# ── USM active, clean response → PASS, usm_audit_passed=True ──
result = evaluator.evaluate(
    "That sounds like a really hard day. I am here with you.",
    ctx_usm,
)
print(f"Verdict          : {result.verdict.value}")
print(f"usm_audit_passed : {result.usm_audit_passed}  (expect: True)")
assert result.verdict == EvaluationVerdict.PASS
assert result.usm_audit_passed is True
print("
✓ USM active, clean response → PASS.")

# %%
# ── USM-1 violation: referencing crisis-state history ──
result = evaluator.evaluate(
    "Last time you mentioned feeling this way, we talked about grounding techniques.",
    ctx_usm,
)
print(f"Verdict          : {result.verdict.value}  (expect: fail)")
print(f"usm_audit_passed : {result.usm_audit_passed}  (expect: False)")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
assert result.usm_audit_passed is False
print("
✓ USM-1 (crisis history reference) correctly blocked.")

# %%
# ── USM-2 violation: clinical inference from memory ──
result = evaluator.evaluate(
    "Based on everything you have shared, this suggests a recurring pattern in how you cope.",
    ctx_usm,
)
print(f"Verdict          : {result.verdict.value}  (expect: fail)")
print(f"usm_audit_passed : {result.usm_audit_passed}  (expect: False)")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ USM-2 (clinical inference) correctly blocked.")

# %%
# ── USM-3 violation: continuous care provider ──
result = evaluator.evaluate(
    "Nikko will continue supporting you on your ongoing journey.",
    ctx_usm,
)
print(f"Verdict          : {result.verdict.value}  (expect: fail)")
print(f"usm_audit_passed : {result.usm_audit_passed}  (expect: False)")
for r in result.rejection_reasons:
    print(f"  {r}")
assert result.verdict == EvaluationVerdict.FAIL
print("
✓ USM-3 (continuity positioning) correctly blocked.")

# %% [markdown]
# ---
# ## Section 4 — Run your own response through the Evaluator
#
# Edit the cell below and run it to test any draft response.
# Change `usm_active` to `True` to also engage the USM audit.

# %%
# ── Sandbox cell — edit freely ──
draft = """
That sounds incredibly overwhelming. It makes sense that you are feeling this way
given everything you have described. You do not have to work through this alone —
speaking with someone you trust, or a professional, can make a real difference.
"""

mode = OperationalMode.COMFORT   # change to GUIDANCE or CRISIS as needed
usm_active = False               # set True to engage USM audit

ctx_custom = make_context(mode=mode, usm_active=usm_active)
result = evaluator.evaluate(draft.strip(), ctx_custom)

print(f"Verdict            : {result.verdict.value}")
print(f"safety_check       : {result.safety_check}")
print(f"tone_check         : {result.tone_check}  (mocked — always True unless real judge is loaded)")
print(f"hallucination_check: {result.hallucination_check}  (mocked)")
print(f"usm_audit_passed   : {result.usm_audit_passed}")
if result.rejection_reasons:
    print("Rejection reasons:")
    for r in result.rejection_reasons:
        print(f"  {r}")
else:
    print("No violations detected.")

# %% [markdown]
# ---
# ## Step 8 summary
#
# | Check | REQ | Status |
# |-------|-----|--------|
# | R1 — Diagnostic statement blocked | REQ-000-060 | ✅ |
# | R2 — Medication/therapy recommendation blocked | REQ-000-062 | ✅ |
# | R5 — Credential claim blocked | REQ-000-050 | ✅ |
# | R7 — Sentience claim blocked | REQ-000-052 | ✅ |
# | R11 — Severity minimisation blocked | REQ-300-130 | ✅ |
# | R15 — Diagnostic phrasing blocked | REQ-100-114 | ✅ |
# | Tone failure → REGENERATE (not FAIL) | REQ-200-100 | ✅ |
# | USM audit — history reference blocked | REQ-850-083 | ✅ |
# | USM audit — clinical inference blocked | REQ-850-083 | ✅ |
# | USM audit — continuity positioning blocked | REQ-850-083 | ✅ |
# | Clean response → PASS | REQ-200-101 | ✅ |
#
# **Next:** Step 9 — Verification Supervisor (structural pipeline gate).
